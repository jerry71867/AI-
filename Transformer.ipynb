# %% [markdown]
# <a href="https://colab.research.google.com/github/jerry71867/AI-/blob/main/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from transformers import BertTokenizer,BertModel
"""
匯入BertTokenizer和BertModel，
BertTokenizer將文本轉換為模型可理解的編碼，
BertModel 是 BERT 預訓練模型。
"""
tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')
#加載了預訓練的BERT分詞器，將輸入文本轉換為BERT所需的編碼格式。
model = BertModel.from_pretrained("bert-base-uncased")
#加載了預訓練的BERT模型，用於處理分詞器編碼後的輸入。
text="my bank account"
encoded_input = tokenizer(text, max_length=100,
         add_special_tokens=True, truncation=True,
         padding=True, return_tensors="pt")
"""
將文本轉換為BERT模型的輸入格式。
add_special_tokens=True表示在文本的開始和結尾添加特殊tokens。
truncation=True表示如果文本長度超過最大長度則進行截斷。
padding=True表示如果文本長度小於最大長度則進行填充。
"""
output = model(**encoded_input)
#將編碼後的輸入傳遞給BERT模型，並獲取模型的輸出。
print(output[0].shape)
#打印模型輸出張量的形狀。
print(output)
#打印模型的完整輸出。
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/file_download.py:1132: FutureWarning: `resume_download` is deprecated and will be removed in version 1.0.0. Downloads always resume when possible. If you want to force a new download, use `force_download=True`.
# ...

# %%
from transformers import AutoTokenizer, GPT2Model
import torch
"""
匯入AutoTokenizer和GPT2Model，並匯入PyTorch的torch庫。
AutoTokenizer用於將文本轉換為模型可理解的編碼，GPT2Model是GPT-2預訓練模型的類。
"""

tokenizer = AutoTokenizer.from_pretrained("openai-community/gpt2")
#加載了預訓練的GPT-2分詞器，把輸入文本轉換為GPT-2所需的編碼格式。
model = GPT2Model.from_pretrained("openai-community/gpt2")
#加載了預訓練的GPT-2模型，用於處理分詞器編碼後的輸入。

inputs = tokenizer("Yes, Hello, my dog is cute", return_tensors="pt")
#將文本轉換為GPT-2模型的輸入格式。
outputs = model(**inputs)
#將編碼後的輸入傳遞給GPT-2模型，並獲取模型的輸出。

last_hidden_states = outputs.last_hidden_state
#提取模型輸出的最後一層隱藏狀態。
print(last_hidden_states.shape)
#打印模型輸出張量的形狀。
print(output)
#打印GPT-2模型的完整輸出，包括所有層的隱藏狀態。
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# torch.Size([1, 8, 768])
# BaseModelOutputWithPoolingAndCrossAttentions(last_hidden_state=tensor([[[-0.5190,  0.2387, -0.3949,  ..., -0.0035,  0.0795,  0.2924],
#          [ 0.5796,  0.4453,  0.0075,  ...,  0.0364,  0.0774,  0.4440],
#          [ 1.2324, -0.3925,  0.2721,  ..., -0.7919, -0.1087, -0.3817],
#          [-0.4921, -0.9572, -0.7413,  ..., -0.0015, -0.3351,  0.4957],
#          [ 0.8211,  0.1658, -0.1855,  ...,  0.0710, -0.6693, -0.3189]]],
#        grad_fn=<NativeLayerNormBackward0>), pooler_output=tensor([[-8.2991e-01, -3.3579e-01, -5.3743e-01,  6.9344e-01,  4.6962e-01,
# ...

# %%
from transformers import GPT2Tokenizer, GPT2LMHeadModel
import torch
"""
匯入GPT2Tokenizer和GPT2LMHeadModel，並匯入PyTorch的torch庫。
GPT2Tokenizer用於將文本轉換為模型可理解的編碼，
GPT2LMHeadModel是帶有語言模型頭部的GPT-2預訓練模型的類。
"""

tokenizer = GPT2Tokenizer.from_pretrained('gpt2')
model = GPT2LMHeadModel.from_pretrained('gpt2')
#加載預訓練的GPT-2模型（帶有語言模型頭部的版本）和分詞器

text = "The quick brown fox jumps over the lazy dog"
inputs = tokenizer(text, return_tensors="pt")
#準備了要處理的文本，並將其轉換為GPT-2模型的輸入格式。

with torch.no_grad():
    outputs = model(**inputs)
#使用torch.no_grad()來禁用梯度計算，並將編碼後的輸入傳遞給GPT-2模型，獲取模型的輸出。

logits = outputs.logits
"""
提取模型的logits。
logits是應用softmax之前的輸出，直接對應於詞彙表的維度
"""

print("Logits shape:", logits.shape)
#展示logits的維度
#維度應該是 [批次大小, 序列長度, 詞彙表大小]
# Out:
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# Logits shape: torch.Size([1, 9, 50257])

# %%
from transformers import MT5EncoderModel, T5Tokenizer
"""
匯入MT5EncoderModel和T5Tokenizer類。
MT5EncoderModel用於加載mT5編碼器模型，
T5Tokenizer用於將文本轉換為模型可理解的編碼格式。
"""

# 加載模型和分詞器
model_name = 'google/mt5-small'
#可以根據需要選擇不同大小的MT5模型
model = MT5EncoderModel.from_pretrained(model_name)
#加載了預訓練的mT5編碼器模型。
tokenizer = T5Tokenizer.from_pretrained(model_name)
#加載了與模型相匹配的T5分詞器。
print(model)
#打印加載的模型的結構和參數。
# Out:
# config.json:   0%|          | 0.00/553 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.20G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/82.0 [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/4.31M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/99.0 [00:00<?, ?B/s]
# You are using the default legacy behaviour of the <class 'transformers.models.t5.tokenization_t5.T5Tokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# MT5EncoderModel(
#   (shared): Embedding(250112, 512)
#   (encoder): MT5Stack(
#     (embed_tokens): Embedding(250112, 512)
#     (block): ModuleList(
#       (0): MT5Block(
#         (layer): ModuleList(
# ...

# %%
from transformers import pipeline
#匯入pipeline函式，使用預訓練模型進行各種NLP任務。

unmasker = pipeline("fill-mask", model="bert-base-uncased")
#創建了一個名為unmasker的pipeline，用於填補掩碼（fill-mask）任務。
result = unmasker("This man works as a [MASK].")
#使用unmasker pipeline對給定的句子進行填補掩碼任務。
print([r["token_str"] for r in result])
#打印模型對掩碼標記的預測結果。

result = unmasker("This woman works as a [MASK].")
#使用unmasker pipeline對另一個句子進行填補掩碼任務。
print([r["token_str"] for r in result])
#打印模型對第二個句子中掩碼標記的預測結果。
# Out:
# Some weights of the model checkpoint at bert-base-uncased were not used when initializing BertForMaskedLM: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight', 'cls.seq_relationship.bias', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing BertForMaskedLM from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForMaskedLM from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ['carpenter', 'lawyer', 'farmer', 'businessman', 'doctor']
# ['nurse', 'maid', 'teacher', 'waitress', 'prostitute']
